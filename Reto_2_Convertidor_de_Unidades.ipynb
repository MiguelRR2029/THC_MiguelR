# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelRR2029/THC_MiguelR/blob/main/Reto_2_Convertidor_de_Unidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Indico el número que debe ingresar el usuario para lo que quierea calcular
print("Si su unidad a convertir es de Longitud ponga 1")
print("Si su unidad convertir es de masa ponga 2")
print("Si su unidad convertir es de tiempo ponga 3")
print("Si desea salir del programa ponga 4")
#Pido que me diga la unidad a calcular
u=float(input("Seleccione unidad a elegir: "))
#En caso de que eligio uno pido que eliga de que sistema a que sistema va aconvertir
if u==1:
  print("Si quiere convertir de Sistema Internacional a Sistema Ingles Ponga 1")
  print("Si quiere convertir de Sistema Ingles a Sistema Internacional Ponga 2")
  print("Si quiere convertir de Sistema Internacional a Sistema Internacional Ponga 3")
  print("Si quiere convertir de Sistema Ingles a Sistema Ingles Ponga 4")
  UL=float(input("seleccione de que sistema a que sistema va a convertir: "))
  #En caso de que sea sistema internacional al ingles Calcular cada caso
  if UL==1:
    U=str(input("seleccione de que unidad convertir (Ejemplo: mm, cm, m, km): "))
    L=str(input("seleccionea que unidad va a convertir(Ejemplo: pulgada, pie, yarda, milla): "))
    if U=="mm" and L=="pulgada":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en pulgadas es: ", Un/25.4)
    elif U=="cm" and L=="pulgada":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en pulgadas es: ", Un/2.54)
    elif U=="m" and L=="pulgada":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en pulgadas es: ", Un*39.37)
    elif U=="km" and L=="pulgada":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en pulgadas es: ", Un*39370)

    elif U=="mm" and L=="pie":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en pies es: ", Un/304.8)
    elif U=="cm" and L=="pie":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en pies es: ", Un/30.48)
    elif U=="m" and L=="pie":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en pies es: ", Un*3.281)
    elif U=="km" and L=="pie":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en pies es: ", Un*3281)

    elif U=="mm" and L=="yarda":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en yardas es: ", Un/914.4)
    elif U=="cm" and L=="yarda":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en yardas es: ", Un/91.44)
    elif U=="m" and L=="yarda":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en yardas es: ", Un*1.094)
    elif U=="km" and L=="yarda":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en yardas es: ", Un*1094)

    elif U=="mm" and L=="milla":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en millas es: ", Un/1609000)
    elif U=="cm" and L=="milla":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en millas es: ", Un/160900)
    elif U=="m" and L=="milla":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en millas es: ", Un/1609)
    elif U=="km" and L=="milla":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en millas es: ", Un/1.609)
  #En caso de que sea sistema ingles al internacional Calcular cada caso
  if UL==2:
    U=str(input("seleccione de que unidad convertir (Ejemplo: pulgada, pie, yarda, milla): "))
    L=str(input("seleccionea que unidad va a convertir (Ejemplo: mm, cm, m, km): "))
    if U=="pulgada" and L=="mm":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en milímetros es: ", Un*25.4)
    elif U=="pie" and L=="mm":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en milímetros es: ", Un*304.8)
    elif U=="yarda" and L=="mm":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yarda en milímetros es: ", Un*914.4)
    elif U=="milla" and L=="mm":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "milla en milímetros es: ", Un*160900)

    elif U=="pulgada" and L=="cm":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en centímetros es: ", Un*2.54)
    elif U=="pie" and L=="cm":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en centímetros es: ", Un*30.48)
    elif U=="yarda" and L=="cm":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yardas en centímetros es: ", Un*91.44)
    elif U=="milla" and L=="cm":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "millas en centímetros es: ", Un*160900)

    elif U=="pulgada" and L=="m":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en metro es: ", Un/39.37)
    elif U=="pie" and L=="m":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en metro es: ", Un/3.281)
    elif U=="yarda" and L=="m":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yarda en metro es: ", Un/1.094)
    elif U=="milla" and L=="m":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "milla en metro es: ", Un*1609)

    elif U=="pulgada" and L=="km":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en kilometros es: ", Un/39370)
    elif U=="pie" and L=="km":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en kilometros es: ", Un/ 3281)
    elif U=="yarda" and L=="km":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yardas en kilometros es: ", Un/1094)
    elif U=="milla" and L=="km":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "millas en kilometros es: ", Un*1609)
    #En caso de que sea sistema internacional al internacional Calcular cada caso
  if UL==3:
    U=str(input("seleccione de que unidad convertir (Ejemplo: mm, cm, m, km): "))
    L=str(input("seleccionea que unidad va a convertir(Ejemplo: mm, cm, m, km): "))
    if U=="mm" and L=="mm":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en milímetros es: ", Un*1)
    elif U=="cm" and L=="mm":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en milímetros es: ", Un/10)
    elif U=="m" and L=="mm":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en milímetros es: ", Un/1000)
    elif U=="km" and L=="mm":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en milímetros es: ", Un/1000000)

    elif U=="mm" and L=="cm":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en pies es: ", Un*10)
    elif U=="cm" and L=="cm":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en pies es: ", Un*1)
    elif U=="m" and L=="cm":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en pies es: ", Un/100)
    elif U=="km" and L=="cm":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en pies es: ", Un/10000)

    elif U=="mm" and L=="m":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en metros es: ", Un*1000)
    elif U=="cm" and L=="m":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en metros es: ", Un*100)
    elif U=="m" and L=="m":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en metros es: ", Un*1)
    elif U=="km" and L=="m":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en metros es: ", Un/1000)

    elif U=="mm" and L=="km":
      Un=float(input("Agrege el número en milímetros: "))
      print(Un, "milímetros en kilómetros es: ", Un*1000000)
    elif U=="cm" and L=="km":
      Un=float(input("Agrege el número en centímetros: "))
      print(Un, "centímetros en kilómetros es: ", Un*100000)
    elif U=="m" and L=="km":
      Un=float(input("Agrege el número en metros: "))
      print(Un, "metros en kilómetros es: ", Un*1000)
    elif U=="km" and L=="km":
      Un=float(input("Agrege el número en kilómetros: "))
      print(Un, "kilómetros en kilómetros es: ", Un*1)
  #En caso de que sea sistema ingles al ingles Calcular cada caso
  if UL==4:
    U=str(input("seleccione de que unidad convertir (Ejemplo: pulgada, pie, yarda, milla): "))
    L=str(input("seleccionea que unidad va a convertir (Ejemplo: pulgada, pie, yarda, milla): "))
    if U=="pulgada" and L=="pulgada":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en pulgadas es: ", Un*1)
    elif U=="pie" and L=="pulgada":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en pulgadas es: ", Un*12)
    elif U=="yarda" and L=="pulgada":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yarda en pulgadas es: ", Un*36)
    elif U=="milla" and L=="pulgada":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "milla en pulgadas es: ", Un*63360)

    elif U=="pulgada" and L=="pie":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en pies es: ", Un/12)
    elif U=="pie" and L=="pie":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en pies es: ", Un*1)
    elif U=="yarda" and L=="pie":
      Un=float(input("Agrege el número en yarda: "))
      print(Un, "yardas en pies es: ", Un*3)
    elif U=="milla" and L=="pie":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "millas en pies es: ", Un*5280)

    elif U=="pulgada" and L=="yarda":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en yardas es: ", Un/36)
    elif U=="pie" and L=="yarda":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en yardas es: ", Un/3)
    elif U=="yarda" and L=="yarda":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yarda en yardas es: ", Un*1)
    elif U=="milla" and L=="yarda":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "milla en yardas es: ", Un*1760)

    elif U=="pulgada" and L=="milla":
      Un=float(input("Agrege el número en pulgadas: "))
      print(Un, "pulgadas en millas es: ", Un/63360)
    elif U=="pie" and L=="milla":
      Un=float(input("Agrege el número en pies: "))
      print(Un, "pies en millas es: ", Un/5280)
    elif U=="yarda" and L=="milla":
      Un=float(input("Agrege el número en yardas: "))
      print(Un, "yardas en millas es: ", Un/1760)
    elif U=="milla" and L=="milla":
      Un=float(input("Agrege el número en millas: "))
      print(Un, "millas en millas es: ", Un*1)

#En caso de que eligio dos pido que eliga de que sistema a que sistema va aconvertir
if u==2:
  print("Si quiere convertir de Sistema Internacional a Sistema Ingles Ponga 1")
  print("Si quiere convertir de Sistema Ingles a Sistema Internacional Ponga 2")
  print("Si quiere convertir de Sistema Internacional a Sistema Internacional Ponga 3")
  print("Si quiere convertir de Sistema Ingles a Sistema Ingles Ponga 4")
  UL=float(input("seleccione de que sistema a que sistema va a convertir: "))
  #En caso de que sea sistema internacional al ingles Calcular cada caso
  if UL==1:
    U=str(input("seleccione de que unidad convertir (Ejemplo: gramo, kg,): "))
    L=str(input("seleccionea que unidad va a convertir(Ejemplo: onza, libra): "))
    if U=="gramo" and L=="onza":
      Un=float(input("Agrege el número en gramos: "))
      print(Un, "gramos en onza es: ", Un/28.35)
    elif U=="kg" and L=="onzas":
      Un=float(input("Agrege el número en kilogramos: "))
      print(Un, "kilogramos en onzas es: ", Un*35.274)
    elif U=="gramo" and L=="libra":
      Un=float(input("Agrege el número en gramos: "))
      print(Un, "gramos en libras es: ", Un/453.6)
    elif U=="kg" and L=="libra":
      Un=float(input("Agrege el número en kilogramos: "))
      print(Un, "kilogramos en libras es: ", Un*2.205)

  #En caso de que sea sistema ingles al internacional Calcular cada caso
  if UL==2:
    U=str(input("seleccione de que unidad convertir (Ejemplo: onza, libra): "))
    L=str(input("seleccionea que unidad va a convertir (Ejemplo: gramo, kg): "))
    if U=="onza" and L=="gramo":
      Un=float(input("Agrege el número en onzas: "))
      print(Un, "onzas en gramos es: ", Un*28.35)
    elif U=="libra" and L=="gramo":
      Un=float(input("Agrege el número en libras: "))
      print(Un, "libras en gramos es: ", Un*453.6)
    elif U=="onzas" and L=="kg":
      Un=float(input("Agrege el número en onzas: "))
      print(Un, "onzas en kilogramos es: ", Un/35.274)
    elif U=="libra" and L=="kg":
      Un=float(input("Agrege el número en libras: "))
      print(Un, "libras en kilogramos es: ", Un/2.205)

    #En caso de que sea sistema internacional al internacional Calcular cada caso
  if UL==3:
    U=str(input("seleccione de que unidad convertir (Ejemplo: gramo, kg): "))
    L=str(input("seleccionea que unidad va a convertir(Ejemplo: kg, gramo): "))
    if U=="gramo" and L=="gramo":
      Un=float(input("Agrege el número en gramos: "))
      print(Un, "gramos en gramos es: ", Un*1)
    elif U=="kg" and L=="gramo":
      Un=float(input("Agrege el número en kilogramos: "))
      print(Un, "kilogramo en gramos es: ", Un*1000)
    elif U=="gramo" and L=="kg":
      Un=float(input("Agrege el número en gramos: "))
      print(Un, "gramos en kilogramos es: ", Un/1000)
    elif U=="kg" and L=="kg":
      Un=float(input("Agrege el número en kilogramos: "))
      print(Un, "kilogramos en kilogramos es: ", Un*1)

  #En caso de que sea sistema ingles al ingles Calcular cada caso
  if UL==4:
    U=str(input("seleccione de que unidad convertir (Ejemplo: onza, libra): "))
    L=str(input("seleccionea que unidad va a convertir (Ejemplo: onza, libra): "))
    if U=="onza" and L=="onza":
      Un=float(input("Agrege el número en onzas: "))
      print(Un, "onzas en onzas es: ", Un*1)
    elif U=="libra" and L=="onza":
      Un=float(input("Agrege el número en libras: "))
      print(Un, "libras en onzas es: ", Un*16)
    elif U=="onza" and L=="libra":
      Un=float(input("Agrege el número en onzas: "))
      print(Un, "onzas en libras es: ", Un/16)
    elif U=="libra" and L=="libra":
      Un=float(input("Agrege el número en libras: "))
      print(Un, "libras en libras es: ", Un*1)

#En caso de que eligio tres pido que eliga de que sistema a que sistema va aconvertir
elif u==3:
    U=str(input("seleccione de que unidad convertir (Ejemplo: ms, s, min, hrs, dias): "))
    L=str(input("seleccionea que unidad va a convertir (Ejemplo: ms, s, min, hrs, dias): "))
    if U=="ms" and L=="ms":
      Un=float(input("Agrege el número en milisegundos: "))
      print(Un, "milisegundos en milisegundos es: ", Un*1)
    elif U=="ms" and L=="s":
      Un=float(input("Agrege el número en milisegundos: "))
      print(Un, "milisegundos en segundos es: ", Un/1000)
    elif U=="ms" and L=="min":
      Un=float(input("Agrege el número en milisegundos: "))
      print(Un, "milisegundos en minutos es: ", Un/60000)
    elif U=="ms" and L=="hrs":
      Un=float(input("Agrege el número en milisegundos: "))
      print(Un, "milisegundos en hrs es: ", Un/3600000)
    elif U=="ms" and L=="dias":
      Un=float(input("Agrege el número en milisegundos: "))
      print(Un, "milisegundos en dias es: ", Un/86400000)

    elif U=="s" and L=="ms":
      Un=float(input("Agrege el número en segundos: "))
      print(Un, "segundos en milisegundos es: ", Un*1000)
    elif U=="s" and L=="s":
      Un=float(input("Agrege el número en segundos: "))
      print(Un, "segundos en segundos es: ", Un*1)
    elif U=="s" and L=="min":
      Un=float(input("Agrege el número en segundos: "))
      print(Un, "segundos en minutos es: ", Un/60)
    elif U=="s" and L=="hrs":
      Un=float(input("Agrege el número en segundos: "))
      print(Un, "segundos en hrs es: ", Un/3600)
    elif U=="s" and L=="dias":
      Un=float(input("Agrege el número en segundos: "))
      print(Un, "segundos en dias es: ", Un/86400)

    elif U=="min" and L=="ms":
      Un=float(input("Agrege el número en minutos: "))
      print(Un, "minutos en milisegundos es: ", Un*60000)
    elif U=="min" and L=="s":
      Un=float(input("Agrege el número en minutos: "))
      print(Un, "minutos en segundos es: ", Un*60)
    elif U=="min" and L=="min":
      Un=float(input("Agrege el número en minutos: "))
      print(Un, "minutos en minutos es: ", Un*1)
    elif U=="min" and L=="hrs":
      Un=float(input("Agrege el número en minutos: "))
      print(Un, "minutos en hrs es: ", Un/60)
    elif U=="min" and L=="dias":
      Un=float(input("Agrege el número en minutos: "))
      print(Un, "minutos en dias es: ", Un/1440)

    elif U=="hrs" and L=="ms":
      Un=float(input("Agrege el número en horas: "))
      print(Un, "horas en milisegundos es: ", Un*360000)
    elif U=="hrs" and L=="s":
      Un=float(input("Agrege el número en horas: "))
      print(Un, "horas en segundos es: ", Un*3600)
    elif U=="hrs" and L=="min":
      Un=float(input("Agrege el número en horas: "))
      print(Un, "horas en minutos es: ", Un*60)
    elif U=="hrs" and L=="hrs":
      Un=float(input("Agrege el número en horas: "))
      print(Un, "horas en hrs es: ", Un*1)
    elif U=="hrs" and L=="dias":
      Un=float(input("Agrege el número en horas: "))
      print(Un, "horas en dias es: ", Un/24)

    elif U=="dias" and L=="ms":
      Un=float(input("Agrege el número en dias: "))
      print(Un, "dias en milisegundos es: ", Un*86400000)
    elif U=="dias" and L=="s":
      Un=float(input("Agrege el número en dias: "))
      print(Un, "dias en segundos es: ", Un*86400)
    elif U=="dias" and L=="min":
      Un=float(input("Agrege el número en dias: "))
      print(Un, "dias en minutos es: ", Un*1440)
    elif U=="dias" and L=="hrs":
      Un=float(input("Agrege el número en dias: "))
      print(Un, "dias en hrs es: ", Un*24)
    elif U=="dias" and L=="dias":
      Un=float(input("Agrege el número en dias: "))
      print(Un, "dias en dias es: ", Un*1)

elif u==4:
  print("Usted salio del programa")

else:
  print("no proporciono información valida")
# Out:
# Si su unidad a convertir es de Longitud ponga 1
# Si su unidad convertir es de masa ponga 2
# Si su unidad convertir es de tiempo ponga 3
# Si desea salir del programa ponga 4
# Seleccione unidad a elegir: 3
# seleccione de que unidad convertir (Ejemplo: ms, s, min, hrs, dias): dias
# seleccionea que unidad va a convertir (Ejemplo: ms, s, min, hrs, dias): s
# Agrege el número en dias: 104
# 104.0 dias en segundos es:  8985600.0
